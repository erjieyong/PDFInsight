# %%
from pdfinsight import pdf_extractor, pdf2df

# %%
df = pdf_extractor("../tests/sample.pdf", toc_pages = 1).tail(50)
df
# Out:
#     page  block        xmin        ymin        xmax        ymax  \
# 31     2     14  108.019997  483.789978  525.608887  495.789978
# 32     2     14  108.019997  498.429993  526.006836  510.429993
# 33     2     14  108.019997  513.069946  528.776794  525.069946
# 34     2     14  108.019997  527.709961  525.704834  539.709961
# 35     2     14  108.019997  542.349976  526.132874  554.349976
# 36     2     15   90.024002  568.270020  100.022675  580.270020
# 37     2     15  108.019997  568.270020  525.692932  580.270020
# 38     2     16  108.019997  582.909973  525.680725  594.909973
# 39     2     16  108.019997  597.549988  525.982788  609.549988
# 40     2     16  108.019997  612.190002  525.668823  624.190002
# 41     2     16  108.019997  626.859985  525.716858  638.859985
# 42     2     16  108.019997  641.500000  525.994934  653.500000
# 43     2     16  301.250000  655.149963  305.324951  663.190002
# 44     2     16  108.019997  656.140015  300.423615  668.140015
# ...

# %%
df[(df['page']==3)&(df['text']=='Column 1')]['cat'].values[0]
# Out:
# 'table'

# %%
df[(df['page']==2)&(df['text']=='Sample PDF')]['cat'].values[0]
# Out:
# 'header'
